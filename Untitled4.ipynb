# %% [markdown]
# <a href="https://colab.research.google.com/github/Oussamayousre/DLL/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets ,layers,models
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train , y_train),(X_test , y_test) = datasets.cifar10.load_data()
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
y_train  = y_train.reshape(y_train.shape[0])
y_train
# Out:
# array([6, 9, 9, ..., 9, 1, 1], dtype=uint8)

# %%
classes = ["airplane" , "automobile","bird","cat","deer" ,"dog","frog","horse","ship","truck"]

# %%
def plot_sample(X,y,index) : 
  plt.figure(figsize=(5,1))
  plt.imshow(X[index])
  plt.xlabel(classes[y[index]])

# %%
plot_sample(X_train , y_train , 10)

# %%
X_train = X_train/255
X_test = X_test/255

# %%
ann = models.Sequential([
          layers.Flatten(input_shape=(32,32,3)),
          layers.Dense(3000,activation='relu'),
          layers.Dense(1000,activation='relu'),
          layers.Dense(10,activation='softmax'),

])
ann.compile(optimizer='SGD',
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])
ann.fit(X_train , y_train, epochs = 10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.8112 - accuracy: 0.3533
# Epoch 2/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.6251 - accuracy: 0.4254
# Epoch 3/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5436 - accuracy: 0.4545
# Epoch 4/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4839 - accuracy: 0.4769
# Epoch 5/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4329 - accuracy: 0.4979
# Epoch 6/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3919 - accuracy: 0.5118
# Epoch 7/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3505 - accuracy: 0.5270
# Epoch 8/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3156 - accuracy: 0.5377
# Epoch 9/10
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.2835 - accuracy: 0.5510
# Epoch 10/10
# ...

# %%
ann.evaluate(X_test , y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.4623 - accuracy: 0.4773
# [1.4622975587844849, 0.4772999882698059]

# %%
cnn = models.Sequential([
          layers.Conv2D(filters = 32 ,kernel_size=(3,3),activation = 'relu', input_shape=(32,32,3)),
          layers.MaxPooling2D(2,2) ,               
 
          layers.Conv2D(filters = 32 ,activation = 'relu' ,  kernel_size=(3,3)),
          layers.MaxPooling2D(2,2) , 

          layers.Flatten(),
          layers.Dense(64,activation='relu'),
          layers.Dense(10,activation='softmax'),

])

# %%
cnn.compile(optimizer='adam',
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])
history = cnn.fit(X_train , y_train,validation_data=(X_test , y_test), epochs = 15)
history
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.5004 - accuracy: 0.4591 - val_loss: 1.2784 - val_accuracy: 0.5455
# Epoch 2/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1976 - accuracy: 0.5748 - val_loss: 1.1351 - val_accuracy: 0.5995
# Epoch 3/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0651 - accuracy: 0.6276 - val_loss: 1.0780 - val_accuracy: 0.6238
# Epoch 4/15
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9812 - accuracy: 0.6590 - val_loss: 1.0687 - val_accuracy: 0.6258
# Epoch 5/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9220 - accuracy: 0.6788 - val_loss: 0.9745 - val_accuracy: 0.6597
# Epoch 6/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8731 - accuracy: 0.6971 - val_loss: 0.9841 - val_accuracy: 0.6523
# Epoch 7/15
# ...

# %%
cnn.evaluate(X_train , y_train)
cnn.evaluate(X_test , y_test)
# Out:
# ...
# 313/313 [==============================] - 1s 3ms/step - loss: 1.0275 - accuracy: 0.6617
# [1.0275146961212158, 0.6617000102996826]

# %%
from matplotlib import pyplot

# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Accuracy')
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_pred = cnn.predict(X_test)

# %%
y_pred
# Out:
# array([[1.57551302e-04, 2.22103277e-04, 1.14886146e-02, ...,
#         3.20357474e-04, 4.03995579e-03, 1.42120825e-05],
#        [6.04945887e-03, 1.32294046e-02, 3.87960517e-06, ...,
#         4.16738599e-09, 9.79471028e-01, 1.24496536e-03],
#        [3.94699782e-01, 4.17419940e-01, 1.20004024e-02, ...,
#         5.34944178e-04, 1.42065346e-01, 1.85241904e-02],
#        ...,
#        [1.22516369e-07, 2.62761422e-08, 2.55732564e-03, ...,
#         1.81683321e-02, 5.57091516e-06, 4.60541862e-08],
#        [4.63194489e-01, 3.26206267e-01, 8.04995373e-03, ...,
#         2.77636270e-03, 4.72451757e-05, 3.86182592e-06],
#        [4.53557550e-06, 1.10279245e-06, 5.46188812e-06, ...,
#         9.94692385e-01, 2.06750794e-09, 2.11685887e-07]], dtype=float32)

# %%
y_pred.shape
# Out:
# (10000, 10)

# %%
for i in np.argmax(y_pred , axis = 1) : 
  print(classes[i])
# Out:
# Streaming output truncated to the last 5000 lines.
# horse
# frog
# ship
# bird
# deer
# dog
# deer
# cat
# horse
# dog
# horse
# dog
# frog
# bird
# horse
# bird
# frog
# truck
# bird
# automobile
# ship
# airplane
# bird
# bird
# automobile
# dog
# bird
# automobile
# automobile
# frog
# deer
# airplane
# bird
# cat
# ship
# dog
# airplane
# ship
# deer
# frog
# cat
# automobile
# bird
# truck
# bird
# horse
# bird
# dog
# truck
# horse
# dog
# truck
# frog
# cat
# truck
# airplane
# truck
# frog
# ship
# deer
# frog
# automobile
# dog
# automobile
# dog
# airplane
# deer
# automobile
# deer
# truck
# cat
# automobile
# bird
# ship
# bird
# frog
# dog
# bird
# ship
# automobile
# horse
# dog
# frog
# truck
# cat
# frog
# cat
# truck
# dog
# frog
# automobile
# airplane
# truck
# ship
# truck
# airplane
# horse
# horse
# bird
# bird
# bird
# dog
# frog
# horse
# airplane
# horse
# dog
# truck
# automobile
# truck
# ship
# frog
# dog
# frog
# horse
# dog
# frog
# horse
# bird
# ...
